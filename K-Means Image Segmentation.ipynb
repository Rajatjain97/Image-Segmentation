# %%
import numpy as np
import matplotlib.pyplot as  plt
import cv2

# %%
im = cv2.imread('Input Image/kmeansImages.jpg') # It reads image as BGR format 
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)

# %%
original_shape = im.shape
print(im.shape)
x = im.shape[0]
y = im.shape[1]
x,y
# Out:
# (168, 300, 3)
# (168, 300)

# %%
# plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(im) # It prints as RGB format
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
def drawImg(labels,colors,k):
    
    labels = labels.reshape((x,y))
    new_img = np.zeros((x,y,3),dtype='uint8')
    for i in range(x):
        for j in range(y):
            new_img[i,j,:] = colors[labels[i][j]]
    new_img = new_img.reshape((original_shape))
    plt.axis("off")
    plt.imshow(new_img)
    plt.savefig('outputs/For k={0}.jpg'.format(k))
    plt.show()

# %%
dominant_colors = 10
all_pixels = im.reshape((-1,3))
for i in range(2,dominant_colors+1):
    km = KMeans(n_clusters=i)
    km.fit(all_pixels)
    centers = km.cluster_centers_
    center = np.array(centers,'uint8')
    
    colors = []
    sp=1
    
    print("For K =",i)
    for each_col in centers:

        plt.subplot(1,dominant_colors,sp) # it adds sub_plot --->> so that all thw plots are visible 
        plt.axis("off")
        colors.append(each_col)
        sp+=1
        
        # color swatch
        a = np.zeros((100,100,3),dtype='uint8')
        a[:,:,:] = each_col
        plt.imshow(a)
    plt.show()
    
    print("New Image:")
    drawImg(km.labels_,colors,i)
# Out:
# For K = 2
# New Image:
# For K = 3
# New Image:
# For K = 4
# New Image:
# For K = 5
# New Image:
# For K = 6
# New Image:
# For K = 7
# New Image:
# For K = 8
# New Image:
# For K = 9
# New Image:
# For K = 10
# New Image:

# %%
# plt.savefig?
